# %%
import pandas as pd

# %%
engagement_dfs = []
for fold in [f"data/engagement/label_0402_fold_{i}" for i in range(5)]:
    train_df = pd.read_csv(f"{fold}/train.csv")
    val_df = pd.read_csv(f"{fold}/val.csv")
    engagement_dfs.extend([train_df, val_df])
engagement_dfs = pd.concat(engagement_dfs, ignore_index=True)
engagement_dfs = engagement_dfs.sort_values(by='video_path', ascending=True)
print(len(engagement_dfs['video_path']), len(engagement_dfs['video_path'].unique())) # TODO: ask TA wtf is this?
engagement_dfs = engagement_dfs.groupby('video_path').agg({
    'engagement': 'mean',
}).reset_index()
engagement_dfs['video_path'] = engagement_dfs['video_path'].apply(lambda x: f"data/engagement/video/{x}.mp4")
print(len(engagement_dfs))
engagement_dfs.head()
# Out:
# 15665 3133
# 3133
#                                           video_path  engagement
# 0  data/engagement/video/Ask_a_Therapist_How_to_M...    0.020000
# 1  data/engagement/video/Ask_a_Therapist_How_to_M...    0.100000
# 2  data/engagement/video/Ask_a_Therapist_How_to_M...    0.010000
# 3  data/engagement/video/Ask_a_Therapist_How_to_M...    0.146667
# 4  data/engagement/video/Ask_a_Therapist_How_to_M...    0.073333

# %%
df_video_path = pd.read_csv('data/engagement/raw_annotations_video_ids.csv')
print(len(df_video_path))
df_video_path.head()
# Out:
# 19281
#    Unnamed: 0  Vid_num                                         Video Link
# 0           0        0                                                NaN
# 1           1        1  data/engagement/video/Te_Awamutu_Community_Boa...
# 2           2        2  data/engagement/video/Group_therapy_video_2/cl...
# 3           3        3  data/engagement/video/Early_Mid_StageCare_Supp...
# 4           4        4  data/engagement/video/Stroke_Buddies_Support_G...

# %%
df_annotations = pd.read_csv('data/engagement/raw_annotations.csv')
print(len(df_annotations))
df_annotations.head()
# Out:
# 19281
#    Unnamed: 0           Annotator Name  \
# 0           0  annotator_id_anonymized
# 1           1                       69
# 2           2                       69
# 3           3                       69
# 4           4                       69
#
#                                      Camera Question  \
# 0  No one is in the video or the camera is turned...
# 1                                              FALSE
# 2                                              FALSE
# 3                                              FALSE
# 4                                              FALSE
#
#                                    Speaking Question  \
# 0  Is the person in the video the main speaker? (...
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#                                     Quality Question  \
# 0  Is the video quality too poor to see the perso...
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#                                                   Q1  \
# 0  The listener produced verbal/audible sounds in...
# 1                                              Never
# 2                                              Never
# 3                                              Never
# 4                                          Sometimes
#
#                                                   Q2  \
# 0  The listener nodded or shook their head in res...
# 1                                              Never
# 2                                             Rarely
# 3                                              Never
# 4                                              Often
#
#                                                   Q3  \
# 0  The listener made facial expressions in respon...
# 1                                              Never
# 2                                             Rarely
# 3                                              Never
# 4                                             Rarely
#
#                                                   Q4  \
# 0  The listener was engaged in some other activit...
# 1                                              Never
# 2                                              Never
# 3                                             Rarely
# 4                                          Sometimes
#
#                                                   Q5  \
# 0  The listener looked away from the speaker. (e....
# 1                                              Never
# 2                                             Rarely
# 3                                             Rarely
# 4                                          Sometimes
#
#                                                   Q6  Vid_num
# 0  Overall, would you say that the listener was s...        0
# 1                                                Yes        1
# 2                                                Yes        2
# 3                                             Unsure        3
# 4                                             Unsure        4

# %%
df = pd.merge(
    df_video_path.drop(columns=['Unnamed: 0']),
    df_annotations.drop(columns=['Unnamed: 0', 'Annotator Name', 'Camera Question', 'Quality Question', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']),
    how='inner',
    left_on='Vid_num',
    right_on='Vid_num'
).rename(columns={
    'Speaking Question': 'is_speaker',
    'Video Link': 'video_path',
})
# remove first row
df = df.iloc[1:]
# take the majority vote for is_speaker column to aggregate the labels
df['is_speaker'] = df['is_speaker'].apply(lambda x: 1 if str(x).lower() == 'yes' else 0)
df = df.groupby('video_path')['is_speaker'].agg(lambda x: 1 if sum(x) > len(x) / 2 else 0).reset_index()
df
# Out:
#                                              video_path  is_speaker
# 0     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 1     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 2     data/engagement/video/Ask_a_Therapist_How_to_M...           1
# 3     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 4     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# ...                                                 ...         ...
# 6395  data/engagement/video/zoom_group_therapy_sessi...           0
# 6396  data/engagement/video/zoom_group_therapy_sessi...           1
# 6397  data/engagement/video/zoom_group_therapy_sessi...           0
# 6398  data/engagement/video/zoom_group_therapy_sessi...           0
# 6399  data/engagement/video/zoom_group_therapy_sessi...           0
#
# [6400 rows x 2 columns]

# %%
df = df.merge(
    engagement_dfs,
    how='left',
    left_on='video_path',
    right_on='video_path'
)
df
# Out:
#                                              video_path  is_speaker  \
# 0     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 1     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 2     data/engagement/video/Ask_a_Therapist_How_to_M...           1
# 3     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 4     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# ...                                                 ...         ...
# 6395  data/engagement/video/zoom_group_therapy_sessi...           0
# 6396  data/engagement/video/zoom_group_therapy_sessi...           1
# 6397  data/engagement/video/zoom_group_therapy_sessi...           0
# 6398  data/engagement/video/zoom_group_therapy_sessi...           0
# 6399  data/engagement/video/zoom_group_therapy_sessi...           0
#
#       engagement
# 0       0.020000
# 1       0.100000
# 2            NaN
# 3       0.010000
# 4            NaN
# ...          ...
# 6395         NaN
# 6396         NaN
# 6397   -0.040000
# 6398   -0.350000
# 6399   -0.216667
#
# [6400 rows x 3 columns]

# %%
df['text_path'] = df['video_path'].apply(lambda x: x.replace('video', 'text').replace('.mp4', '.txt'))
df['audio_path'] = df['video_path'].apply(lambda x: x.replace('video', 'audio').replace('.mp4', '.wav'))
df['openface_path'] = df['video_path'].apply(lambda x: x.replace('video', 'featopenface').replace('.mp4', '.csv'))
df['clip_uid'] = df['video_path'].apply(lambda x: '_'.join(x.split('data/engagement/video/')[-1].split('.mp4')[0].split('/')[:-1]))
print(len(df))
df
# Out:
# 6400
#                                              video_path  is_speaker  \
# 0     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 1     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 2     data/engagement/video/Ask_a_Therapist_How_to_M...           1
# 3     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 4     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# ...                                                 ...         ...
# 6395  data/engagement/video/zoom_group_therapy_sessi...           0
# 6396  data/engagement/video/zoom_group_therapy_sessi...           1
# 6397  data/engagement/video/zoom_group_therapy_sessi...           0
# 6398  data/engagement/video/zoom_group_therapy_sessi...           0
# 6399  data/engagement/video/zoom_group_therapy_sessi...           0
#
#       engagement                                          text_path  \
# 0       0.020000  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 1       0.100000  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 2            NaN  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 3       0.010000  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 4            NaN  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# ...          ...                                                ...
# 6395         NaN  data/engagement/text/zoom_group_therapy_sessio...
# 6396         NaN  data/engagement/text/zoom_group_therapy_sessio...
# 6397   -0.040000  data/engagement/text/zoom_group_therapy_sessio...
# 6398   -0.350000  data/engagement/text/zoom_group_therapy_sessio...
# 6399   -0.216667  data/engagement/text/zoom_group_therapy_sessio...
#
#                                              audio_path  \
# 0     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 1     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 2     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 3     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 4     data/engagement/audio/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 6395  data/engagement/audio/zoom_group_therapy_sessi...
# 6396  data/engagement/audio/zoom_group_therapy_sessi...
# 6397  data/engagement/audio/zoom_group_therapy_sessi...
# 6398  data/engagement/audio/zoom_group_therapy_sessi...
# 6399  data/engagement/audio/zoom_group_therapy_sessi...
#
#                                           openface_path  \
# 0     data/engagement/featopenface/Ask_a_Therapist_H...
# 1     data/engagement/featopenface/Ask_a_Therapist_H...
# 2     data/engagement/featopenface/Ask_a_Therapist_H...
# 3     data/engagement/featopenface/Ask_a_Therapist_H...
# 4     data/engagement/featopenface/Ask_a_Therapist_H...
# ...                                                 ...
# 6395  data/engagement/featopenface/zoom_group_therap...
# 6396  data/engagement/featopenface/zoom_group_therap...
# 6397  data/engagement/featopenface/zoom_group_therap...
# 6398  data/engagement/featopenface/zoom_group_therap...
# 6399  data/engagement/featopenface/zoom_group_therap...
#
#                                                clip_uid
# 0     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 1     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 2     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 3     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 4     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# ...                                                 ...
# 6395              zoom_group_therapy_session_1_clip0070
# 6396              zoom_group_therapy_session_1_clip0070
# 6397              zoom_group_therapy_session_1_clip0070
# 6398              zoom_group_therapy_session_1_clip0070
# 6399              zoom_group_therapy_session_1_clip0070
#
# [6400 rows x 7 columns]

# %%
df_listeners
# Out:
#                                              video_path  is_speaker  \
# 0     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 1     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 2     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 3     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# 4     data/engagement/video/Ask_a_Therapist_How_to_M...           0
# ...                                                 ...         ...
# 3128  data/engagement/video/zoom_group_therapy_sessi...           0
# 3129  data/engagement/video/zoom_group_therapy_sessi...           0
# 3130  data/engagement/video/zoom_group_therapy_sessi...           0
# 3131  data/engagement/video/zoom_group_therapy_sessi...           0
# 3132  data/engagement/video/zoom_group_therapy_sessi...           0
#
#       engagement                                          text_path  \
# 0       0.020000  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 1       0.100000  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 2       0.010000  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 3       0.146667  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 4       0.073333  data/engagement/text/Ask_a_Therapist_How_to_Ma...
# ...          ...                                                ...
# 3128   -0.276667  data/engagement/text/zoom_group_therapy_sessio...
# 3129   -0.150000  data/engagement/text/zoom_group_therapy_sessio...
# 3130   -0.040000  data/engagement/text/zoom_group_therapy_sessio...
# 3131   -0.350000  data/engagement/text/zoom_group_therapy_sessio...
# 3132   -0.216667  data/engagement/text/zoom_group_therapy_sessio...
#
#                                              audio_path  \
# 0     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 1     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 2     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 3     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 4     data/engagement/audio/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 3128  data/engagement/audio/zoom_group_therapy_sessi...
# 3129  data/engagement/audio/zoom_group_therapy_sessi...
# 3130  data/engagement/audio/zoom_group_therapy_sessi...
# 3131  data/engagement/audio/zoom_group_therapy_sessi...
# 3132  data/engagement/audio/zoom_group_therapy_sessi...
#
#                                           openface_path  \
# 0     data/engagement/featopenface/Ask_a_Therapist_H...
# 1     data/engagement/featopenface/Ask_a_Therapist_H...
# 2     data/engagement/featopenface/Ask_a_Therapist_H...
# 3     data/engagement/featopenface/Ask_a_Therapist_H...
# 4     data/engagement/featopenface/Ask_a_Therapist_H...
# ...                                                 ...
# 3128  data/engagement/featopenface/zoom_group_therap...
# 3129  data/engagement/featopenface/zoom_group_therap...
# 3130  data/engagement/featopenface/zoom_group_therap...
# 3131  data/engagement/featopenface/zoom_group_therap...
# 3132  data/engagement/featopenface/zoom_group_therap...
#
#                                                clip_uid
# 0     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 1     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 2     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 3     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 4     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# ...                                                 ...
# 3128              zoom_group_therapy_session_1_clip0069
# 3129              zoom_group_therapy_session_1_clip0069
# 3130              zoom_group_therapy_session_1_clip0070
# 3131              zoom_group_therapy_session_1_clip0070
# 3132              zoom_group_therapy_session_1_clip0070
#
# [3133 rows x 7 columns]

# %%
df_speakers = df[df['is_speaker'] == 1]
df_listeners = df[df['is_speaker'] == 0]

df_listener_speaker = df_listeners.merge(df_speakers, on='clip_uid', suffixes=('_listener', '_speaker'))

df_listener_speaker = df_listener_speaker[[
    'clip_uid',
    'video_path_listener', 'text_path_listener', 'audio_path_listener', 'openface_path_listener',
    'video_path_speaker', 'text_path_speaker', 'audio_path_speaker', 'openface_path_speaker',
    'engagement_listener'
]]

df_listener_speaker.columns = [
    'listener_clip_uid',
    'listener_video_path', 'listener_text_path', 'listener_audio_path', 'listener_openface_path',
    'speaker_video_path', 'speaker_text_path', 'speaker_audio_path', 'speaker_openface_path',
    'engagement'
]
df_listener_speaker
# Out:
#                                       listener_clip_uid  \
# 0     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 1     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 2     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 3     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 4     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# ...                                                 ...
# 4777              zoom_group_therapy_session_1_clip0069
# 4778              zoom_group_therapy_session_1_clip0070
# 4779              zoom_group_therapy_session_1_clip0070
# 4780              zoom_group_therapy_session_1_clip0070
# 4781              zoom_group_therapy_session_1_clip0070
#
#                                     listener_video_path  \
# 0     data/engagement/video/Ask_a_Therapist_How_to_M...
# 1     data/engagement/video/Ask_a_Therapist_How_to_M...
# 2     data/engagement/video/Ask_a_Therapist_How_to_M...
# 3     data/engagement/video/Ask_a_Therapist_How_to_M...
# 4     data/engagement/video/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 4777  data/engagement/video/zoom_group_therapy_sessi...
# 4778  data/engagement/video/zoom_group_therapy_sessi...
# 4779  data/engagement/video/zoom_group_therapy_sessi...
# 4780  data/engagement/video/zoom_group_therapy_sessi...
# 4781  data/engagement/video/zoom_group_therapy_sessi...
#
#                                      listener_text_path  \
# 0     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 1     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 2     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 3     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 4     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# ...                                                 ...
# 4777  data/engagement/text/zoom_group_therapy_sessio...
# 4778  data/engagement/text/zoom_group_therapy_sessio...
# 4779  data/engagement/text/zoom_group_therapy_sessio...
# 4780  data/engagement/text/zoom_group_therapy_sessio...
# 4781  data/engagement/text/zoom_group_therapy_sessio...
#
#                                     listener_audio_path  \
# 0     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 1     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 2     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 3     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 4     data/engagement/audio/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 4777  data/engagement/audio/zoom_group_therapy_sessi...
# 4778  data/engagement/audio/zoom_group_therapy_sessi...
# 4779  data/engagement/audio/zoom_group_therapy_sessi...
# 4780  data/engagement/audio/zoom_group_therapy_sessi...
# 4781  data/engagement/audio/zoom_group_therapy_sessi...
#
#                                  listener_openface_path  \
# 0     data/engagement/featopenface/Ask_a_Therapist_H...
# 1     data/engagement/featopenface/Ask_a_Therapist_H...
# 2     data/engagement/featopenface/Ask_a_Therapist_H...
# 3     data/engagement/featopenface/Ask_a_Therapist_H...
# 4     data/engagement/featopenface/Ask_a_Therapist_H...
# ...                                                 ...
# 4777  data/engagement/featopenface/zoom_group_therap...
# 4778  data/engagement/featopenface/zoom_group_therap...
# 4779  data/engagement/featopenface/zoom_group_therap...
# 4780  data/engagement/featopenface/zoom_group_therap...
# 4781  data/engagement/featopenface/zoom_group_therap...
#
#                                      speaker_video_path  \
# 0     data/engagement/video/Ask_a_Therapist_How_to_M...
# 1     data/engagement/video/Ask_a_Therapist_How_to_M...
# 2     data/engagement/video/Ask_a_Therapist_How_to_M...
# 3     data/engagement/video/Ask_a_Therapist_How_to_M...
# 4     data/engagement/video/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 4777  data/engagement/video/zoom_group_therapy_sessi...
# 4778  data/engagement/video/zoom_group_therapy_sessi...
# 4779  data/engagement/video/zoom_group_therapy_sessi...
# 4780  data/engagement/video/zoom_group_therapy_sessi...
# 4781  data/engagement/video/zoom_group_therapy_sessi...
#
#                                       speaker_text_path  \
# 0     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 1     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 2     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 3     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 4     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# ...                                                 ...
# 4777  data/engagement/text/zoom_group_therapy_sessio...
# 4778  data/engagement/text/zoom_group_therapy_sessio...
# 4779  data/engagement/text/zoom_group_therapy_sessio...
# 4780  data/engagement/text/zoom_group_therapy_sessio...
# 4781  data/engagement/text/zoom_group_therapy_sessio...
#
#                                      speaker_audio_path  \
# 0     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 1     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 2     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 3     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 4     data/engagement/audio/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 4777  data/engagement/audio/zoom_group_therapy_sessi...
# 4778  data/engagement/audio/zoom_group_therapy_sessi...
# 4779  data/engagement/audio/zoom_group_therapy_sessi...
# 4780  data/engagement/audio/zoom_group_therapy_sessi...
# 4781  data/engagement/audio/zoom_group_therapy_sessi...
#
#                                   speaker_openface_path  engagement
# 0     data/engagement/featopenface/Ask_a_Therapist_H...    0.020000
# 1     data/engagement/featopenface/Ask_a_Therapist_H...    0.100000
# 2     data/engagement/featopenface/Ask_a_Therapist_H...    0.010000
# 3     data/engagement/featopenface/Ask_a_Therapist_H...         NaN
# 4     data/engagement/featopenface/Ask_a_Therapist_H...         NaN
# ...                                                 ...         ...
# 4777  data/engagement/featopenface/zoom_group_therap...   -0.150000
# 4778  data/engagement/featopenface/zoom_group_therap...         NaN
# 4779  data/engagement/featopenface/zoom_group_therap...   -0.040000
# 4780  data/engagement/featopenface/zoom_group_therap...   -0.350000
# 4781  data/engagement/featopenface/zoom_group_therap...   -0.216667
#
# [4782 rows x 10 columns]

# %%
# drop those with NaN engagement
df_listener_speaker = df_listener_speaker.dropna(subset=['engagement'])
df_listener_speaker = df_listener_speaker.reset_index(drop=True)
df_listener_speaker.to_csv('engagement_listener_speaker.csv', index=False)
df_listener_speaker
# Out:
#                                       listener_clip_uid  \
# 0     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 1     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 2     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 3     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# 4     Ask_a_Therapist_How_to_Manage_Mental_Health_Du...
# ...                                                 ...
# 2825              zoom_group_therapy_session_1_clip0069
# 2826              zoom_group_therapy_session_1_clip0069
# 2827              zoom_group_therapy_session_1_clip0070
# 2828              zoom_group_therapy_session_1_clip0070
# 2829              zoom_group_therapy_session_1_clip0070
#
#                                     listener_video_path  \
# 0     data/engagement/video/Ask_a_Therapist_How_to_M...
# 1     data/engagement/video/Ask_a_Therapist_How_to_M...
# 2     data/engagement/video/Ask_a_Therapist_How_to_M...
# 3     data/engagement/video/Ask_a_Therapist_How_to_M...
# 4     data/engagement/video/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 2825  data/engagement/video/zoom_group_therapy_sessi...
# 2826  data/engagement/video/zoom_group_therapy_sessi...
# 2827  data/engagement/video/zoom_group_therapy_sessi...
# 2828  data/engagement/video/zoom_group_therapy_sessi...
# 2829  data/engagement/video/zoom_group_therapy_sessi...
#
#                                      listener_text_path  \
# 0     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 1     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 2     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 3     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 4     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# ...                                                 ...
# 2825  data/engagement/text/zoom_group_therapy_sessio...
# 2826  data/engagement/text/zoom_group_therapy_sessio...
# 2827  data/engagement/text/zoom_group_therapy_sessio...
# 2828  data/engagement/text/zoom_group_therapy_sessio...
# 2829  data/engagement/text/zoom_group_therapy_sessio...
#
#                                     listener_audio_path  \
# 0     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 1     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 2     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 3     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 4     data/engagement/audio/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 2825  data/engagement/audio/zoom_group_therapy_sessi...
# 2826  data/engagement/audio/zoom_group_therapy_sessi...
# 2827  data/engagement/audio/zoom_group_therapy_sessi...
# 2828  data/engagement/audio/zoom_group_therapy_sessi...
# 2829  data/engagement/audio/zoom_group_therapy_sessi...
#
#                                  listener_openface_path  \
# 0     data/engagement/featopenface/Ask_a_Therapist_H...
# 1     data/engagement/featopenface/Ask_a_Therapist_H...
# 2     data/engagement/featopenface/Ask_a_Therapist_H...
# 3     data/engagement/featopenface/Ask_a_Therapist_H...
# 4     data/engagement/featopenface/Ask_a_Therapist_H...
# ...                                                 ...
# 2825  data/engagement/featopenface/zoom_group_therap...
# 2826  data/engagement/featopenface/zoom_group_therap...
# 2827  data/engagement/featopenface/zoom_group_therap...
# 2828  data/engagement/featopenface/zoom_group_therap...
# 2829  data/engagement/featopenface/zoom_group_therap...
#
#                                      speaker_video_path  \
# 0     data/engagement/video/Ask_a_Therapist_How_to_M...
# 1     data/engagement/video/Ask_a_Therapist_How_to_M...
# 2     data/engagement/video/Ask_a_Therapist_How_to_M...
# 3     data/engagement/video/Ask_a_Therapist_How_to_M...
# 4     data/engagement/video/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 2825  data/engagement/video/zoom_group_therapy_sessi...
# 2826  data/engagement/video/zoom_group_therapy_sessi...
# 2827  data/engagement/video/zoom_group_therapy_sessi...
# 2828  data/engagement/video/zoom_group_therapy_sessi...
# 2829  data/engagement/video/zoom_group_therapy_sessi...
#
#                                       speaker_text_path  \
# 0     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 1     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 2     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 3     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# 4     data/engagement/text/Ask_a_Therapist_How_to_Ma...
# ...                                                 ...
# 2825  data/engagement/text/zoom_group_therapy_sessio...
# 2826  data/engagement/text/zoom_group_therapy_sessio...
# 2827  data/engagement/text/zoom_group_therapy_sessio...
# 2828  data/engagement/text/zoom_group_therapy_sessio...
# 2829  data/engagement/text/zoom_group_therapy_sessio...
#
#                                      speaker_audio_path  \
# 0     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 1     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 2     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 3     data/engagement/audio/Ask_a_Therapist_How_to_M...
# 4     data/engagement/audio/Ask_a_Therapist_How_to_M...
# ...                                                 ...
# 2825  data/engagement/audio/zoom_group_therapy_sessi...
# 2826  data/engagement/audio/zoom_group_therapy_sessi...
# 2827  data/engagement/audio/zoom_group_therapy_sessi...
# 2828  data/engagement/audio/zoom_group_therapy_sessi...
# 2829  data/engagement/audio/zoom_group_therapy_sessi...
#
#                                   speaker_openface_path  engagement
# 0     data/engagement/featopenface/Ask_a_Therapist_H...    0.020000
# 1     data/engagement/featopenface/Ask_a_Therapist_H...    0.100000
# 2     data/engagement/featopenface/Ask_a_Therapist_H...    0.010000
# 3     data/engagement/featopenface/Ask_a_Therapist_H...    0.090000
# 4     data/engagement/featopenface/Ask_a_Therapist_H...    0.126667
# ...                                                 ...         ...
# 2825  data/engagement/featopenface/zoom_group_therap...   -0.276667
# 2826  data/engagement/featopenface/zoom_group_therap...   -0.150000
# 2827  data/engagement/featopenface/zoom_group_therap...   -0.040000
# 2828  data/engagement/featopenface/zoom_group_therap...   -0.350000
# 2829  data/engagement/featopenface/zoom_group_therap...   -0.216667
#
# [2830 rows x 10 columns]
